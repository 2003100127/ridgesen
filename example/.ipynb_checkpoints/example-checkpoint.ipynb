# %%
import os,sys
sys.path.append('../src/')
from BeijingSen import beijingSen

# %%
# plot ridge (k) analysis for industry
plot_sen = beijingSen().sensitivity(
    file_path='../data/industry.dat',
    industry='industry',
)

# %%
# print parameters of a ridge regression model under ridge k=0.4
est_sen = beijingSen().general(
    file_path='../data/industry.dat',
    k=0.4
)
est_sen
# Out:
# [-0.5413783788240059,
#  0.21548545249980994,
#  0.8164447327847106,
#  -0.04472893505090987,
#  -0.03248254510282097,
#  0.24465308934038368,
#  0.9469992889324894]
